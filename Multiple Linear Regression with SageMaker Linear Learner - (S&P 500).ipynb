# %% [markdown]
# # TASK #1: IMPORT KEY LIBRARIES/DATASETS

# %%
# Import Numpy and check the version
import numpy as np
print(np.__version__)
# Out:
# 1.26.4

# %%
# Import Numpy and check the version
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
# Updgrade Numpy version
# !pip3 install numpy --upgrade
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (1.26.4)
# Collecting numpy
#   Using cached numpy-2.1.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Using cached numpy-2.1.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.1.1 requires nvidia-ml-py3==7.352.0, which is not installed.
# amazon-sagemaker-jupyter-ai-q-developer 1.0.9 requires numpy<=2.0.1, but you have numpy 2.1.2 which is incompatible.
# autogluon-common 1.1.1 requires numpy<1.29,>=1.21, but you have numpy 2.1.2 which is incompatible.
# autogluon-core 1.1.1 requires numpy<1.29,>=1.21, but you have numpy 2.1.2 which is incompatible.
# autogluon-core 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-features 1.1.1 requires numpy<1.29,>=1.21, but you have numpy 2.1.2 which is incompatible.
# autogluon-features 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 1.1.1 requires numpy<1.29,>=1.21, but you have numpy 2.1.2 which is incompatible.
# autogluon-multimodal 1.1.1 requires omegaconf<2.3.0,>=2.1.1, but you have omegaconf 2.3.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 1.1.1 requires transformers[sentencepiece]<4.41.0,>=4.38.0, but you have transformers 4.45.2 which is incompatible.
# autogluon-tabular 1.1.1 requires numpy<1.29,>=1.21, but you have numpy 2.1.2 which is incompatible.
# autogluon-tabular 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-timeseries 1.1.1 requires gluonts==0.15.1, but you have gluonts 0.14.3 which is incompatible.
# autogluon-timeseries 1.1.1 requires numpy<1.29,>=1.21, but you have numpy 2.1.2 which is incompatible.
# autogluon-timeseries 1.1.1 requires transformers[sentencepiece]<4.41.0,>=4.38.0, but you have transformers 4.45.2 which is incompatible.
# gluonts 0.14.3 requires numpy~=1.16, but you have numpy 2.1.2 which is incompatible.
# hdijupyterutils 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.3 which is incompatible.
# langchain 0.2.5 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.1.2 which is incompatible.
# langchain-aws 0.1.16 requires numpy<2,>=1, but you have numpy 2.1.2 which is incompatible.
# langchain-community 0.2.12 requires langchain<0.3.0,>=0.2.13, but you have langchain 0.2.5 which is incompatible.
# langchain-community 0.2.12 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.1.2 which is incompatible.
# mlflow 2.15.1 requires numpy<2, but you have numpy 2.1.2 which is incompatible.
# nptyping 2.4.1 requires numpy<2.0.0,>=1.20.0; python_version >= "3.8", but you have numpy 2.1.2 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.2 which is incompatible.
# pyarrow 15.0.2 requires numpy<2,>=1.16.6, but you have numpy 2.1.2 which is incompatible.
# sagemaker 2.227.0 requires boto3<2.0,>=1.34.142, but you have boto3 1.34.131 which is incompatible.
# sagemaker 2.227.0 requires numpy<2.0,>=1.9.0, but you have numpy 2.1.2 which is incompatible.
# scipy 1.12.0 requires numpy<1.29.0,>=1.22.4, but you have numpy 2.1.2 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.3 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.1.2 which is incompatible.
# Successfully installed numpy-2.1.2

# %%
# Updgrade Pandas version
# !pip3 install pandas --upgrade
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip3 install --upgrade scip      ###Numpy Error Fix
# !pip install bertopic
# !pip3 uninstall -y awscli boto3 botocore s3transfer   ### Bucket Fix  'is_s3express_bucket'
# !pip3 install awscli
# Out:
# Collecting scip
#   Using cached scip-0.1.12-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from scip) (2.1.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.11/site-packages (from scip) (10.4.0)
# Requirement already satisfied: dask>=2022.01.1 in /opt/conda/lib/python3.11/site-packages (from dask[distributed]>=2022.01.1->scip) (2024.8.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from scip) (8.1.7)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.11/site-packages (from scip) (0.20.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from scip) (6.0.2)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.11/site-packages (from scip) (0.20.3)
# Collecting zarr (from scip)
#   Using cached zarr-2.18.3-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.11/site-packages (from scip) (15.0.2)
# Collecting anndata (from scip)
#   Using cached anndata-0.10.9-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from scip) (2.2.3)
# Requirement already satisfied: numba in /opt/conda/lib/python3.11/site-packages (from scip) (0.60.0)
# Collecting aicsimageio (from scip)
#   Using cached aicsimageio-4.14.0-py2.py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: cloudpickle>=1.5.0 in /opt/conda/lib/python3.11/site-packages (from dask>=2022.01.1->dask[distributed]>=2022.01.1->scip) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/lib/python3.11/site-packages (from dask>=2022.01.1->dask[distributed]>=2022.01.1->scip) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from dask>=2022.01.1->dask[distributed]>=2022.01.1->scip) (24.1)
# Requirement already satisfied: partd>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from dask>=2022.01.1->dask[distributed]>=2022.01.1->scip) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from dask>=2022.01.1->dask[distributed]>=2022.01.1->scip) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/conda/lib/python3.11/site-packages (from dask>=2022.01.1->dask[distributed]>=2022.01.1->scip) (6.10.0)
# Requirement already satisfied: distributed==2024.8.0 in /opt/conda/lib/python3.11/site-packages (from dask[distributed]>=2022.01.1->scip) (2024.8.0)
# Requirement already satisfied: jinja2>=2.10.3 in /opt/conda/lib/python3.11/site-packages (from distributed==2024.8.0->dask[distributed]>=2022.01.1->scip) (3.1.4)
# Requirement already satisfied: locket>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from distributed==2024.8.0->dask[distributed]>=2022.01.1->scip) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from distributed==2024.8.0->dask[distributed]>=2022.01.1->scip) (1.0.8)
# Requirement already satisfied: psutil>=5.7.2 in /opt/conda/lib/python3.11/site-packages (from distributed==2024.8.0->dask[distributed]>=2022.01.1->scip) (5.9.8)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /opt/conda/lib/python3.11/site-packages (from distributed==2024.8.0->dask[distributed]>=2022.01.1->scip) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from distributed==2024.8.0->dask[distributed]>=2022.01.1->scip) (2.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /opt/conda/lib/python3.11/site-packages (from distributed==2024.8.0->dask[distributed]>=2022.01.1->scip) (6.4.1)
# Requirement already satisfied: urllib3>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from distributed==2024.8.0->dask[distributed]>=2022.01.1->scip) (1.26.19)
# Requirement already satisfied: zict>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from distributed==2024.8.0->dask[distributed]>=2022.01.1->scip) (3.0.0)
# Requirement already satisfied: imagecodecs>=2020.5.30 in /opt/conda/lib/python3.11/site-packages (from aicsimageio->scip) (2024.6.1)
# Requirement already satisfied: lxml<5,>=4.6 in /opt/conda/lib/python3.11/site-packages (from aicsimageio->scip) (4.9.4)
# Collecting ome-types>=0.3.4 (from aicsimageio->scip)
#   Using cached ome_types-0.5.2-py3-none-any.whl.metadata (11 kB)
# Collecting ome-zarr>=0.6.1 (from aicsimageio->scip)
#   Using cached ome_zarr-0.9.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: wrapt>=1.12 in /opt/conda/lib/python3.11/site-packages (from aicsimageio->scip) (1.16.0)
# Collecting resource-backed-dask-array>=0.1.0 (from aicsimageio->scip)
#   Using cached resource_backed_dask_array-0.1.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting tifffile<2023.3.15,>=2021.8.30 (from aicsimageio->scip)
#   Using cached tifffile-2023.2.28-py3-none-any.whl.metadata (30 kB)
# Collecting xarray>=0.16.1 (from aicsimageio->scip)
#   Using cached xarray-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting xmlschema (from aicsimageio->scip)
#   Using cached xmlschema-3.4.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting zarr (from scip)
#   Using cached zarr-2.15.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting asciitree (from zarr->scip)
#   Using cached asciitree-0.3.3-py3-none-any.whl
# Collecting fasteners (from zarr->scip)
#   Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting numcodecs>=0.10.0 (from zarr->scip)
#   Using cached numcodecs-0.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Collecting array-api-compat!=1.5,>1.4 (from anndata->scip)
#   Using cached array_api_compat-1.9-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: h5py>=3.1 in /opt/conda/lib/python3.11/site-packages (from anndata->scip) (3.11.0)
# Collecting natsort (from anndata->scip)
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: scipy>1.8 in /opt/conda/lib/python3.11/site-packages (from anndata->scip) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->scip) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->scip) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->scip) (2024.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba->scip) (0.43.0)
# Collecting numpy (from scip)
#   Using cached numpy-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.11/site-packages (from scikit-image->scip) (3.3)
# Requirement already satisfied: imageio>=2.4.1 in /opt/conda/lib/python3.11/site-packages (from scikit-image->scip) (2.35.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from scikit-image->scip) (1.7.0)
# Requirement already satisfied: lazy_loader>=0.1 in /opt/conda/lib/python3.11/site-packages (from scikit-image->scip) (0.4)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask>=2022.01.1->dask[distributed]>=2022.01.1->scip) (3.20.0)
# Collecting pydantic-compat>=0.1.0 (from ome-types>=0.3.4->aicsimageio->scip)
#   Using cached pydantic_compat-0.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pydantic>=1.10.0 in /opt/conda/lib/python3.11/site-packages (from ome-types>=0.3.4->aicsimageio->scip) (1.10.17)
# Collecting xsdata<24.4,>=23.6 (from ome-types>=0.3.4->aicsimageio->scip)
#   Using cached xsdata-24.3.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: aiohttp<4 in /opt/conda/lib/python3.11/site-packages (from ome-zarr>=0.6.1->aicsimageio->scip) (3.9.5)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from ome-zarr>=0.6.1->aicsimageio->scip) (2.32.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->scip) (1.16.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from resource-backed-dask-array>=0.1.0->aicsimageio->scip) (4.12.2)
# Collecting elementpath<5.0.0,>=4.4.0 (from xmlschema->aicsimageio->scip)
#   Using cached elementpath-4.5.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4->ome-zarr>=0.6.1->aicsimageio->scip) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4->ome-zarr>=0.6.1->aicsimageio->scip) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4->ome-zarr>=0.6.1->aicsimageio->scip) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4->ome-zarr>=0.6.1->aicsimageio->scip) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp<4->ome-zarr>=0.6.1->aicsimageio->scip) (1.9.4)
# Collecting s3fs (from fsspec[s3]!=2021.07.0,>=0.8->ome-zarr>=0.6.1->aicsimageio->scip)
#   Downloading s3fs-2024.10.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2>=2.10.3->distributed==2024.8.0->dask[distributed]>=2022.01.1->scip) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->ome-zarr>=0.6.1->aicsimageio->scip) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->ome-zarr>=0.6.1->aicsimageio->scip) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->ome-zarr>=0.6.1->aicsimageio->scip) (2024.7.4)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/conda/lib/python3.11/site-packages (from s3fs->fsspec[s3]!=2021.07.0,>=0.8->ome-zarr>=0.6.1->aicsimageio->scip) (2.13.2)
# INFO: pip is looking at multiple versions of s3fs to determine which version is compatible with other requirements. This could take a while.
#   Using cached s3fs-2024.9.0-py3-none-any.whl.metadata (1.6 kB)
#   Using cached s3fs-2024.6.1-py3-none-any.whl.metadata (1.6 kB)
#   Using cached s3fs-2024.6.0-py3-none-any.whl.metadata (1.6 kB)
#   Using cached s3fs-2024.5.0-py3-none-any.whl.metadata (1.6 kB)
#   Using cached s3fs-2024.3.1-py3-none-any.whl.metadata (1.6 kB)
#   Using cached s3fs-2024.3.0-py3-none-any.whl.metadata (1.6 kB)
#   Using cached s3fs-2024.2.0-py3-none-any.whl.metadata (1.6 kB)
# INFO: pip is still looking at multiple versions of s3fs to determine which version is compatible with other requirements. This could take a while.
#   Using cached s3fs-2023.12.2-py3-none-any.whl.metadata (1.6 kB)
#   Using cached s3fs-2023.12.1-py3-none-any.whl.metadata (1.6 kB)
#   Using cached s3fs-2023.10.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting aiobotocore~=2.7.0 (from s3fs->fsspec[s3]!=2021.07.0,>=0.8->ome-zarr>=0.6.1->aicsimageio->scip)
#   Using cached aiobotocore-2.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting s3fs (from fsspec[s3]!=2021.07.0,>=0.8->ome-zarr>=0.6.1->aicsimageio->scip)
#   Using cached s3fs-2023.9.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting aiobotocore~=2.5.4 (from s3fs->fsspec[s3]!=2021.07.0,>=0.8->ome-zarr>=0.6.1->aicsimageio->scip)
#   Using cached aiobotocore-2.5.4-py3-none-any.whl.metadata (19 kB)
# Collecting s3fs (from fsspec[s3]!=2021.07.0,>=0.8->ome-zarr>=0.6.1->aicsimageio->scip)
#   Using cached s3fs-2023.9.1-py3-none-any.whl.metadata (1.6 kB)
# INFO: This is taking longer than usual. You might need to provide the dependency resolver with stricter constraints to reduce runtime. See https://pip.pypa.io/warnings/backtracking for guidance. If you want to abort this run, press Ctrl + C.
#   Using cached s3fs-2023.9.0-py3-none-any.whl.metadata (1.6 kB)
#   Using cached s3fs-2023.6.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting botocore<1.31.18,>=1.31.17 (from aiobotocore~=2.5.4->s3fs->fsspec[s3]!=2021.07.0,>=0.8->ome-zarr>=0.6.1->aicsimageio->scip)
#   Using cached botocore-1.31.17-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.11/site-packages (from aiobotocore~=2.5.4->s3fs->fsspec[s3]!=2021.07.0,>=0.8->ome-zarr>=0.6.1->aicsimageio->scip) (0.11.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.31.18,>=1.31.17->aiobotocore~=2.5.4->s3fs->fsspec[s3]!=2021.07.0,>=0.8->ome-zarr>=0.6.1->aicsimageio->scip) (1.0.1)
# Using cached scip-0.1.12-py3-none-any.whl (61 kB)
# Using cached aicsimageio-4.14.0-py2.py3-none-any.whl (138 kB)
# Using cached zarr-2.15.0-py3-none-any.whl (206 kB)
# Using cached anndata-0.10.9-py3-none-any.whl (128 kB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Using cached array_api_compat-1.9-py3-none-any.whl (49 kB)
# Using cached numcodecs-0.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.9 MB)
# Using cached ome_types-0.5.2-py3-none-any.whl (248 kB)
# Using cached ome_zarr-0.9.0-py3-none-any.whl (37 kB)
# Using cached resource_backed_dask_array-0.1.0-py2.py3-none-any.whl (8.0 kB)
# Using cached tifffile-2023.2.28-py3-none-any.whl (216 kB)
# Using cached xarray-2024.9.0-py3-none-any.whl (1.2 MB)
# Using cached fasteners-0.19-py3-none-any.whl (18 kB)
# Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Using cached xmlschema-3.4.2-py3-none-any.whl (417 kB)
# Using cached elementpath-4.5.0-py3-none-any.whl (228 kB)
# Using cached pydantic_compat-0.1.2-py3-none-any.whl (13 kB)
# Using cached xsdata-24.3.1-py3-none-any.whl (224 kB)
# Using cached s3fs-2023.6.0-py3-none-any.whl (28 kB)
# Using cached aiobotocore-2.5.4-py3-none-any.whl (73 kB)
# Using cached botocore-1.31.17-py3-none-any.whl (11.1 MB)
# Installing collected packages: asciitree, array-api-compat, xsdata, numpy, natsort, fasteners, elementpath, xmlschema, tifffile, pydantic-compat, numcodecs, botocore, zarr, xarray, ome-types, anndata, aiobotocore, s3fs, resource-backed-dask-array, ome-zarr, aicsimageio, scip
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.2
#     Uninstalling numpy-2.1.2:
#       Successfully uninstalled numpy-2.1.2
#   Attempting uninstall: tifffile
#     Found existing installation: tifffile 2024.8.10
#     Uninstalling tifffile-2024.8.10:
#       Successfully uninstalled tifffile-2024.8.10
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.34.131
#     Uninstalling botocore-1.34.131:
#       Successfully uninstalled botocore-1.34.131
#   Attempting uninstall: aiobotocore
#     Found existing installation: aiobotocore 2.13.2
#     Uninstalling aiobotocore-2.13.2:
#       Successfully uninstalled aiobotocore-2.13.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.1.1 requires nvidia-ml-py3==7.352.0, which is not installed.
# amazon-sagemaker-jupyter-scheduler 3.1.3 requires aiobotocore<3,>=2.7, but you have aiobotocore 2.5.4 which is incompatible.
# amazon-sagemaker-sql-editor 0.1.11 requires aiobotocore<3,>=2.7.0, but you have aiobotocore 2.5.4 which is incompatible.
# amazon-sagemaker-sql-editor 0.1.11 requires botocore<2,>=1.31.64, but you have botocore 1.31.17 which is incompatible.
# autogluon-core 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-features 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 1.1.1 requires omegaconf<2.3.0,>=2.1.1, but you have omegaconf 2.3.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 1.1.1 requires transformers[sentencepiece]<4.41.0,>=4.38.0, but you have transformers 4.45.2 which is incompatible.
# autogluon-tabular 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-timeseries 1.1.1 requires gluonts==0.15.1, but you have gluonts 0.14.3 which is incompatible.
# autogluon-timeseries 1.1.1 requires transformers[sentencepiece]<4.41.0,>=4.38.0, but you have transformers 4.45.2 which is incompatible.
# boto3 1.34.131 requires botocore<1.35.0,>=1.34.131, but you have botocore 1.31.17 which is incompatible.
# hdijupyterutils 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.3 which is incompatible.
# langchain-community 0.2.12 requires langchain<0.3.0,>=0.2.13, but you have langchain 0.2.5 which is incompatible.
# s3transfer 0.10.2 requires botocore<2.0a.0,>=1.33.2, but you have botocore 1.31.17 which is incompatible.
# sagemaker 2.227.0 requires boto3<2.0,>=1.34.142, but you have boto3 1.34.131 which is incompatible.
# sagemaker-jupyterlab-extension-common 0.1.21 requires aiobotocore>=2.7.0, but you have aiobotocore 2.5.4 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.3 which is incompatible.
# Successfully installed aicsimageio-4.14.0 aiobotocore-2.5.4 anndata-0.10.9 array-api-compat-1.9 asciitree-0.3.3 botocore-1.31.17 elementpath-4.5.0 fasteners-0.19 natsort-8.4.0 numcodecs-0.13.1 numpy-1.26.4 ome-types-0.5.2 ome-zarr-0.9.0 pydantic-compat-0.1.2 resource-backed-dask-array-0.1.0 s3fs-2023.6.0 scip-0.1.12 tifffile-2023.2.28 xarray-2024.9.0 xmlschema-3.4.2 xsdata-24.3.1 zarr-2.15.0
# Requirement already satisfied: bertopic in /opt/conda/lib/python3.11/site-packages (0.16.4)
# Requirement already satisfied: hdbscan>=0.8.29 in /opt/conda/lib/python3.11/site-packages (from bertopic) (0.8.39)
# Requirement already satisfied: numpy>=1.20.0 in /opt/conda/lib/python3.11/site-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /opt/conda/lib/python3.11/site-packages (from bertopic) (2.2.3)
# Requirement already satisfied: plotly>=4.7.0 in /opt/conda/lib/python3.11/site-packages (from bertopic) (5.23.0)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /opt/conda/lib/python3.11/site-packages (from bertopic) (1.4.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /opt/conda/lib/python3.11/site-packages (from bertopic) (3.2.1)
# Requirement already satisfied: tqdm>=4.41.1 in /opt/conda/lib/python3.11/site-packages (from bertopic) (4.66.5)
# Requirement already satisfied: umap-learn>=0.5.0 in /opt/conda/lib/python3.11/site-packages (from bertopic) (0.5.6)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.11/site-packages (from hdbscan>=0.8.29->bertopic) (1.12.0)
# Requirement already satisfied: joblib>=1.0 in /opt/conda/lib/python3.11/site-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.1.5->bertopic) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.1.5->bertopic) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.1.5->bertopic) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from plotly>=4.7.0->bertopic) (8.5.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from plotly>=4.7.0->bertopic) (24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /opt/conda/lib/python3.11/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.45.2)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from sentence-transformers>=0.4.1->bertopic) (2.3.1.post100)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/conda/lib/python3.11/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.24.5)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.11/site-packages (from sentence-transformers>=0.4.1->bertopic) (10.4.0)
# Requirement already satisfied: numba>=0.51.2 in /opt/conda/lib/python3.11/site-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.11/site-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.4.4)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# WARNING: Skipping awscli as it is not installed.
# Found existing installation: boto3 1.34.131
# Uninstalling boto3-1.34.131:
#   Successfully uninstalled boto3-1.34.131
# Found existing installation: botocore 1.31.17
# Uninstalling botocore-1.31.17:
#   Successfully uninstalled botocore-1.31.17
# Found existing installation: s3transfer 0.10.2
# Uninstalling s3transfer-0.10.2:
#   Successfully uninstalled s3transfer-0.10.2
# Collecting awscli
#   Downloading awscli-1.35.13-py3-none-any.whl.metadata (11 kB)
# Collecting botocore==1.35.47 (from awscli)
#   Downloading botocore-1.35.47-py3-none-any.whl.metadata (5.7 kB)
# Collecting docutils<0.17,>=0.10 (from awscli)
#   Using cached docutils-0.16-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from awscli)
#   Using cached s3transfer-0.10.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /opt/conda/lib/python3.11/site-packages (from awscli) (6.0.2)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in /opt/conda/lib/python3.11/site-packages (from awscli) (0.4.6)
# Collecting rsa<4.8,>=3.1.2 (from awscli)
#   Using cached rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from botocore==1.35.47->awscli) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore==1.35.47->awscli) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore==1.35.47->awscli) (1.26.19)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.35.47->awscli) (1.16.0)
# Downloading awscli-1.35.13-py3-none-any.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 84.1 MB/s eta 0:00:00
# Downloading botocore-1.35.47-py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 104.8 MB/s eta 0:00:00
# Using cached docutils-0.16-py2.py3-none-any.whl (548 kB)
# Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Using cached s3transfer-0.10.3-py3-none-any.whl (82 kB)
# Installing collected packages: rsa, docutils, botocore, s3transfer, awscli
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# amazon-q-developer-jupyterlab-ext 3.2.0 requires boto3, which is not installed.
# amazon-sagemaker-jupyter-ai-q-developer 1.0.9 requires boto3, which is not installed.
# amazon-sagemaker-sql-editor 0.1.11 requires boto3<2,>=1.29.6, which is not installed.
# aws-glue-sessions 1.0.6 requires boto3>=1.21.31, which is not installed.
# pyathena 3.9.0 requires boto3>=1.26.4, which is not installed.
# redshift-connector 2.1.2 requires boto3<2.0.0,>=1.9.201, which is not installed.
# amazon-sagemaker-sql-editor 0.1.11 requires aiobotocore<3,>=2.7.0, but you have aiobotocore 2.5.4 which is incompatible.
# aiobotocore 2.5.4 requires botocore<1.31.18,>=1.31.17, but you have botocore 1.35.47 which is incompatible.
# Successfully installed awscli-1.35.13 botocore-1.35.47 docutils-0.16 rsa-4.7.2 s3transfer-0.10.3

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.35.47-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: botocore<1.36.0,>=1.35.47 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.35.47)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from boto3) (0.10.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.36.0,>=1.35.47->boto3) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.36.0,>=1.35.47->boto3) (1.26.19)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.47->boto3) (1.16.0)
# Downloading boto3-1.35.47-py3-none-any.whl (139 kB)
# Installing collected packages: boto3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.1.1 requires nvidia-ml-py3==7.352.0, which is not installed.
# amazon-sagemaker-sql-editor 0.1.11 requires aiobotocore<3,>=2.7.0, but you have aiobotocore 2.5.4 which is incompatible.
# amazon-sagemaker-sql-magic 0.1.3 requires sqlparse==0.5.0, but you have sqlparse 0.5.1 which is incompatible.
# autogluon-core 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-features 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 1.1.1 requires omegaconf<2.3.0,>=2.1.1, but you have omegaconf 2.3.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 1.1.1 requires transformers[sentencepiece]<4.41.0,>=4.38.0, but you have transformers 4.45.2 which is incompatible.
# autogluon-tabular 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-timeseries 1.1.1 requires gluonts==0.15.1, but you have gluonts 0.14.3 which is incompatible.
# autogluon-timeseries 1.1.1 requires transformers[sentencepiece]<4.41.0,>=4.38.0, but you have transformers 4.45.2 which is incompatible.
# langchain-aws 0.1.16 requires boto3<1.35.0,>=1.34.131, but you have boto3 1.35.47 which is incompatible.
# Successfully installed boto3-1.35.47

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px # Interactive Data Visualization

# %%
# Read the CSV file 
stock_df = pd.read_csv("S&P500_Stock_Data.csv")

# %% [markdown]
# # Task #2: PERFORM EDA AND PREPARE THE DATA FOR TRAINING

# %%
# Load the top 6 instances
stock_df.head(6)
# Out:
#    Interest Rates  Employment  S&P 500 Price
# 0        1.943859   55.413571    2206.680582
# 1        2.258229   59.546305    2486.474488
# 2        2.215863   57.414687    2405.868337
# 3        1.977960   49.908353    2140.434475
# 4        2.437723   52.035492    2411.275663
# 5        2.143637   56.060598    2187.344909

# %%
# Load the bottom 6 instances 
stock_df.tail(6)
# Out:
#      Interest Rates  Employment  S&P 500 Price
# 994        1.868835   60.543377    2065.424594
# 995        2.528420   52.390828    2578.699184
# 996        2.643571   54.626204    2573.865933
# 997        2.009644   57.004357    2004.911218
# 998        2.201656   62.447790    2344.098981
# 999        2.180638   46.297034    2156.133786

# %%
# Display the feature columns
stock_df.columns
# Out:
# Index(['Interest Rates', 'Employment', 'S&P 500 Price'], dtype='object')

# %%
# Check the shape of the dataframe
stock_df.shape
# Out:
# (1000, 3)

# %%
# Check if any missing values are present in the dataframe
stock_df.isnull().sum()
# Out:
# Interest Rates    0
# Employment        0
# S&P 500 Price     0
# dtype: int64

# %%
stock_df = stock_df.dropna()

# %%
stock_df.dtypes
# Out:
# Interest Rates    float64
# Employment        float64
# S&P 500 Price     float64
# dtype: object

# %%
# check if there are any Null values
sns.heatmap(stock_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >

# %%
sns.jointplot(x = 'Employment', y = 'S&P 500 Price', data=stock_df);

# %%
sns.jointplot(x = 'Interest Rates',y = 'S&P 500 Price', data = stock_df);

# %%
sns.pairplot(stock_df);

# %%
y = stock_df['S&P 500 Price']

# %%
X = stock_df[['Interest Rates', 'Employment']]

# %%
# X = np.array(X)

# %%
# y = np.array(y)

# %% [markdown]
# # TASK #3: TRAIN A LINEAR LEARNER MODEL USING SAGEMAKER TO SOLVE MULTIPLE LINEAR REGRESSION PROBLEM

# %%
# Convert the datatype to float32 (to run Linear Learner successfully)
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size = 0.2)

# %%
# Boto3 is the Amazon Web Services (AWS) Software Development Kit (SDK) for Python
# Boto3 allows Python developer to write software that makes use of services like Amazon S3 and Amazon EC2

import sagemaker
import boto3

# Let's create a Sagemaker session
sagemaker_session = sagemaker.Session()

# Let's define the S3 bucket and prefix that we want to use in this session
# bucket = 'aws-ml-10days' # bucket named 'aws-ml-10days' was created beforehand

bucket = sagemaker_session.default_bucket() 
prefix = 'linear_learner' # prefix is the subfolder within the bucket.

# Let's get the execution role for the notebook instance. 
# This is the IAM role that you created when you created your notebook instance. You pass the role to the training job.
# Note that AWS Identity and Access Management (IAM) role that Amazon SageMaker can assume to perform tasks on your behalf (for example, reading training results, called model artifacts, from the S3 bucket and writing training results to Amazon S3). 
role = sagemaker.get_execution_role()
print(role)
# Out:
# arn:aws:iam::213950924470:role/service-role/AmazonSageMaker-ExecutionRole-20240522T185225

# %%
X_train.shape
# Out:
# (800, 2)

# %%
y_train.shape
# Out:
# (800,)

# %%
# y_train = y_train[:,0]

# %%
y_train.shape
# Out:
# (800,)

# %%
import io # The io module allows for dealing with various types of I/O (text I/O, binary I/O and raw I/O). 
import numpy as np
import sagemaker.amazon.common as smac # sagemaker common libary

# Code below converts the data in numpy array format to RecordIO format
# This is the format required by Sagemaker Linear Learner 

buf = io.BytesIO() # create an in-memory byte array (buf is a buffer I will be writing to)
smac.write_numpy_to_dense_tensor(buf, X_train, y_train)
buf.seek(0) 
# When you write to in-memory byte arrays, it increments 1 every time you write to it
# Let's reset that back to zero
# Out:
# 0

# %%
import os

# Code to upload RecordIO data to S3
 
# Key refers to the name of the file    
key = 'linear-train-data'

# The following code uploads the data in record-io format to S3 bucket to be accessed later for training
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)

# Let's print out the training data location in s3
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# uploaded training data location: s3://sagemaker-us-east-1-213950924470/linear_learner/train/linear-train-data

# %%
# create an output placeholder in S3 bucket to store the linear learner output

output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('Training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# Training artifacts will be uploaded to: s3://sagemaker-us-east-1-213950924470/linear_learner/output

# %%
# Note that this code leverages the new SageMaker SDK 2.0
# Check this for the list of changes from AWS SageMaker SDK 1.0 to 2.0: https://sagemaker.readthedocs.io/en/stable/v2.html

# This code is used to get the training container of sagemaker built-in algorithms
# all we have to do is to specify the name of the algorithm that we want to use

# Let's obtain a reference to the linearLearner container image
# Note that all regression models are named estimators
# You don't have to specify (hardcode) the region, get_image_uri will get the current region name using boto3.Session
container = sagemaker.image_uris.retrieve("linear-learner", boto3.Session().region_name)


# This is using the old AWS SageMAker SDK 1.0 (You need to use get_image_uri and note that attribute order is different as well)
# from sagemaker.amazon.amazon_estimator import get_image_uri
# container = get_image_uri(boto3.Session().region_name, 'linear-learner')
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: 1.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.

# %%
# We have pass in the container, the type of instance that we would like to use for training 
# output path and sagemaker session into the Estimator. 
# We can also specify how many instances we would like to use for training

linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       instance_count = 1, 
                                       instance_type = 'ml.m4.xlarge',
                                       output_path = output_location,
                                       sagemaker_session = sagemaker_session)


# We can tune parameters like the number of features that we are passing in, type of predictor like 'regressor' or 'classifier', mini batch size, epochs
# Train 32 different versions of the model and will get the best out of them (built-in parameters optimization!)

linear.set_hyperparameters(feature_dim = 2,
                           predictor_type = 'regressor',
                           mini_batch_size = 100,
                           epochs = 100,
                           num_models = 32,
                           loss = 'absolute_loss')

# Now we are ready to pass in the training data from S3 to train the linear learner model

linear.fit({'train': s3_train_data})

# Let's see the progress using cloudwatch logs
# Out:
# INFO:sagemaker:Creating training-job with name: linear-learner-2024-10-24-02-34-17-064
# 2024-10-24 02:34:18 Starting - Starting the training job...
# 2024-10-24 02:34:32 Starting - Preparing the instances for training...
# 2024-10-24 02:35:09 Downloading - Downloading input data...
# 2024-10-24 02:35:45 Downloading - Downloading the training image......
# 2024-10-24 02:36:46 Training - Training image download completed. Training in progress....
# 2024-10-24 02:37:23 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [10/24/2024 02:37:13 INFO 139918617806656] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [10/24/2024 02:37:13 INFO 139918617806656] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '100', 'feature_dim': '2', 'loss': 'absolute_loss', 'mini_batch_size': '100', 'num_models': '32', 'predictor_type': 'regressor'}
# [10/24/2024 02:37:13 INFO 139918617806656] Final configuration: {'mini_batch_size': '100', 'epochs': '100', 'feature_dim': '2', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '32', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [10/24/2024 02:37:16 WARNING 139918617806656] Loggers have already been setup.
# [10/24/2024 02:37:16 INFO 139918617806656] Final configuration: {'mini_batch_size': '100', 'epochs': '100', 'feature_dim': '2', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '32', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [10/24/2024 02:37:16 WARNING 139918617806656] Loggers have already been setup.
# Process 7 is a worker.
# [10/24/2024 02:37:16 INFO 139918617806656] Using default worker.
# [10/24/2024 02:37:16 INFO 139918617806656] Checkpoint loading and saving are disabled.
# [2024-10-24 02:37:16.661] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 12, "num_examples": 1, "num_bytes": 5200}
# [10/24/2024 02:37:16 INFO 139918617806656] Create Store: local
# [2024-10-24 02:37:16.709] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 47, "num_examples": 8, "num_bytes": 41600}
# [10/24/2024 02:37:16 INFO 139918617806656] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f40c72b34c0>
# [10/24/2024 02:37:16 INFO 139918617806656] Scaling model computed with parameters:
#  {'stdev_label':
# [193.85036]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [0.23964033 4.9580784 ]
# <NDArray 2 @cpu(0)>, 'mean_label':
# [2319.8628]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [ 2.1959386 56.224487 ]
# <NDArray 2 @cpu(0)>}
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [10/24/2024 02:37:16 INFO 139918617806656] nvidia-smi: took 0.033 seconds to run.
# [10/24/2024 02:37:16 INFO 139918617806656] nvidia-smi identified 0 GPUs.
# [10/24/2024 02:37:16 INFO 139918617806656] Number of GPUs being used: 0
# #metrics {"StartTime": 1729737436.811094, "EndTime": 1729737436.8111293, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 900.0, "count": 1, "min": 900, "max": 900}, "Total Batches Seen": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Max Records Seen Between Resets": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Max Batches Seen Between Resets": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2024-10-24 02:37:16.939] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 128, "num_examples": 8, "num_bytes": 41600}
# #metrics {"StartTime": 1729737436.9401586, "EndTime": 1729737436.9402359, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7866683864593506, "count": 1, "min": 0.7866683864593506, "max": 0.7866683864593506}}}
# #metrics {"StartTime": 1729737436.9403412, "EndTime": 1729737436.940354, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7915207958221435, "count": 1, "min": 0.7915207958221435, "max": 0.7915207958221435}}}
# #metrics {"StartTime": 1729737436.9403832, "EndTime": 1729737436.9403915, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.797384614944458, "count": 1, "min": 0.797384614944458, "max": 0.797384614944458}}}
# #metrics {"StartTime": 1729737436.940419, "EndTime": 1729737436.9404259, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7773909187316894, "count": 1, "min": 0.7773909187316894, "max": 0.7773909187316894}}}
# #metrics {"StartTime": 1729737436.9404483, "EndTime": 1729737436.940473, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6624063491821289, "count": 1, "min": 0.6624063491821289, "max": 0.6624063491821289}}}
# #metrics {"StartTime": 1729737436.9404976, "EndTime": 1729737436.9405046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6128365564346313, "count": 1, "min": 0.6128365564346313, "max": 0.6128365564346313}}}
# #metrics {"StartTime": 1729737436.9406285, "EndTime": 1729737436.940663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.648254108428955, "count": 1, "min": 0.648254108428955, "max": 0.648254108428955}}}
# #metrics {"StartTime": 1729737436.9407094, "EndTime": 1729737436.9407175, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6465055656433105, "count": 1, "min": 0.6465055656433105, "max": 0.6465055656433105}}}
# #metrics {"StartTime": 1729737436.9407413, "EndTime": 1729737436.9407625, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8284830093383789, "count": 1, "min": 0.8284830093383789, "max": 0.8284830093383789}}}
# #metrics {"StartTime": 1729737436.9407854, "EndTime": 1729737436.9407933, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7589885711669921, "count": 1, "min": 0.7589885711669921, "max": 0.7589885711669921}}}
# #metrics {"StartTime": 1729737436.9408174, "EndTime": 1729737436.9408238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7601549434661865, "count": 1, "min": 0.7601549434661865, "max": 0.7601549434661865}}}
# #metrics {"StartTime": 1729737436.9408488, "EndTime": 1729737436.9408555, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7713117027282714, "count": 1, "min": 0.7713117027282714, "max": 0.7713117027282714}}}
# #metrics {"StartTime": 1729737436.9409091, "EndTime": 1729737436.940916, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6243541240692139, "count": 1, "min": 0.6243541240692139, "max": 0.6243541240692139}}}
# #metrics {"StartTime": 1729737436.9409447, "EndTime": 1729737436.9409509, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6397204446792603, "count": 1, "min": 0.6397204446792603, "max": 0.6397204446792603}}}
# #metrics {"StartTime": 1729737436.9409728, "EndTime": 1729737436.940979, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6376378583908081, "count": 1, "min": 0.6376378583908081, "max": 0.6376378583908081}}}
# #metrics {"StartTime": 1729737436.9410272, "EndTime": 1729737436.9410343, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1700.0, "count": 1, "min": 1700, "max": 1700}, "Total Batches Seen": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Max Records Seen Between Resets": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Max Batches Seen Between Resets": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Number of Batches Since Last Reset": {"sum": 8.0, "count": 1, "min": 8, "max": 8}}}
# [10/24/2024 02:37:16 INFO 139918617806656] #throughput_metric: host=algo-1, train throughput=5674.774687928617 records/second
# [2024-10-24 02:37:17.055] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 102, "num_examples": 8, "num_bytes": 41600}
# #metrics {"StartTime": 1729737437.0551481, "EndTime": 1729737437.0552154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.739226598739624, "count": 1, "min": 0.739226598739624, "max": 0.739226598739624}}}
# #metrics {"StartTime": 1729737437.0552804, "EndTime": 1729737437.0552938, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.744896583557129, "count": 1, "min": 0.744896583557129, "max": 0.744896583557129}}}
# #metrics {"StartTime": 1729737437.0553298, "EndTime": 1729737437.0553396, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7503934383392334, "count": 1, "min": 0.7503934383392334, "max": 0.7503934383392334}}}
# #metrics {"StartTime": 1729737437.055371, "EndTime": 1729737437.055391, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7303757286071777, "count": 1, "min": 0.7303757286071777, "max": 0.7303757286071777}}}
# #metrics {"StartTime": 1729737437.0554204, "EndTime": 1729737437.055429, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3227396059036255, "count": 1, "min": 0.3227396059036255, "max": 0.3227396059036255}}}
# #metrics {"StartTime": 1729737437.0554576, "EndTime": 1729737437.0554655, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.325015652179718, "count": 1, "min": 0.325015652179718, "max": 0.325015652179718}}}
# #metrics {"StartTime": 1729737437.055494, "EndTime": 1729737437.055503, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3304091429710388, "count": 1, "min": 0.3304091429710388, "max": 0.3304091429710388}}}
# #metrics {"StartTime": 1729737437.0555325, "EndTime": 1729737437.0555408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3244689130783081, "count": 1, "min": 0.3244689130783081, "max": 0.3244689130783081}}}
# #metrics {"StartTime": 1729737437.0555701, "EndTime": 1729737437.0555778, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7822431945800781, "count": 1, "min": 0.7822431945800781, "max": 0.7822431945800781}}}
# #metrics {"StartTime": 1729737437.055607, "EndTime": 1729737437.0556154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7119287109375, "count": 1, "min": 0.7119287109375, "max": 0.7119287109375}}}
# #metrics {"StartTime": 1729737437.0556471, "EndTime": 1729737437.0556562, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.715099172592163, "count": 1, "min": 0.715099172592163, "max": 0.715099172592163}}}
# #metrics {"StartTime": 1729737437.055698, "EndTime": 1729737437.0557077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7259958553314209, "count": 1, "min": 0.7259958553314209, "max": 0.7259958553314209}}}
# #metrics {"StartTime": 1729737437.055739, "EndTime": 1729737437.0557477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31804915189743044, "count": 1, "min": 0.31804915189743044, "max": 0.31804915189743044}}}
# #metrics {"StartTime": 1729737437.0557783, "EndTime": 1729737437.0557873, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3215854263305664, "count": 1, "min": 0.3215854263305664, "max": 0.3215854263305664}}}
# #metrics {"StartTime": 1729737437.0558188, "EndTime": 1729737437.0558274, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3301256847381592, "count": 1, "min": 0.3301256847381592, "max": 0.3301256847381592}}}
# #metrics {"StartTime": 1729737437.0558584, "EndTime": 1729737437.0558672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3270153284072876, "count": 1, "min": 0.3270153284072876, "max": 0.3270153284072876}}}
# #metrics {"StartTime": 1729737437.0559027, "EndTime": 1729737437.055912, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7249546623229981, "count": 1, "min": 0.7249546623229981, "max": 0.7249546623229981}}}
# #metrics {"StartTime": 1729737437.055942, "EndTime": 1729737437.0559509, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7089907169342041, "count": 1, "min": 0.7089907169342041, "max": 0.7089907169342041}}}
# #metrics {"StartTime": 1729737437.0559819, "EndTime": 1729737437.055992, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7599586868286132, "count": 1, "min": 0.7599586868286132, "max": 0.7599586868286132}}}
# #metrics {"StartTime": 1729737437.0560324, "EndTime": 1729737437.0560412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7088174247741699, "count": 1, "min": 0.7088174247741699, "max": 0.7088174247741699}}}
# #metrics {"StartTime": 1729737437.0560708, "EndTime": 1729737437.0560803, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.35342416286468503, "count": 1, "min": 0.35342416286468503, "max": 0.35342416286468503}}}
# #metrics {"StartTime": 1729737437.0561101, "EndTime": 1729737437.0561192, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3562683153152466, "count": 1, "min": 0.3562683153152466, "max": 0.3562683153152466}}}
# #metrics {"StartTime": 1729737437.0561504, "EndTime": 1729737437.0561597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.32417731523513793, "count": 1, "min": 0.32417731523513793, "max": 0.32417731523513793}}}
# #metrics {"StartTime": 1729737437.0561898, "EndTime": 1729737437.056199, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3275156474113464, "count": 1, "min": 0.3275156474113464, "max": 0.3275156474113464}}}
# #metrics {"StartTime": 1729737437.0562296, "EndTime": 1729737437.0562396, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8096503448486329, "count": 1, "min": 0.8096503448486329, "max": 0.8096503448486329}}}
# #metrics {"StartTime": 1729737437.0562706, "EndTime": 1729737437.0562792, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7994192790985107, "count": 1, "min": 0.7994192790985107, "max": 0.7994192790985107}}}
# #metrics {"StartTime": 1729737437.0563092, "EndTime": 1729737437.0563188, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8029792881011963, "count": 1, "min": 0.8029792881011963, "max": 0.8029792881011963}}}
# #metrics {"StartTime": 1729737437.056355, "EndTime": 1729737437.0563645, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7998035621643066, "count": 1, "min": 0.7998035621643066, "max": 0.7998035621643066}}}
# #metrics {"StartTime": 1729737437.056395, "EndTime": 1729737437.0564034, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8174833583831788, "count": 1, "min": 0.8174833583831788, "max": 0.8174833583831788}}}
# #metrics {"StartTime": 1729737437.0564349, "EndTime": 1729737437.0564446, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.806891098022461, "count": 1, "min": 0.806891098022461, "max": 0.806891098022461}}}
# #metrics {"StartTime": 1729737437.0564766, "EndTime": 1729737437.0564857, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8053243350982666, "count": 1, "min": 0.8053243350982666, "max": 0.8053243350982666}}}
# #metrics {"StartTime": 1729737437.056516, "EndTime": 1729737437.0565245, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8009087467193603, "count": 1, "min": 0.8009087467193603, "max": 0.8009087467193603}}}
# [10/24/2024 02:37:17 INFO 139918617806656] #quality_metric: host=algo-1, epoch=1, train absolute_loss_objective <loss>=0.739226598739624
# [10/24/2024 02:37:17 INFO 139918617806656] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=absolute_loss_objective, value=0.31804915189743044
# [10/24/2024 02:37:17 INFO 139918617806656] Epoch 1: Loss improved. Updating best model
# [10/24/2024 02:37:17 INFO 139918617806656] Saving model for epoch: 1
# [10/24/2024 02:37:17 INFO 139918617806656] Saved checkpoint to "/tmp/tmpyz1mu52d/mx-mod-0000.params"
# [10/24/2024 02:37:17 INFO 139918617806656] #progress_metric: host=algo-1, completed 2.0 % of epochs
# #metrics {"StartTime": 1729737436.9524567, "EndTime": 1729737437.0640693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2500.0, "count": 1, "min": 2500, "max": 2500}, "Total Batches Seen": {"sum": 25.0, "count": 1, "min": 25, "max": 25}, "Max Records Seen Between Resets": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Max Batches Seen Between Resets": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Number of Batches Since Last Reset": {"sum":
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7987498664855956, "count": 1, "min": 0.7987498664855956, "max": 0.7987498664855956}}}
# #metrics {"StartTime": 1729737438.553514, "EndTime": 1729737438.553522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7988582611083984, "count": 1, "min": 0.7988582611083984, "max": 0.7988582611083984}}}
# #metrics {"StartTime": 1729737438.5535522, "EndTime": 1729737438.5535614, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8169601726531982, "count": 1, "min": 0.8169601726531982, "max": 0.8169601726531982}}}
# #metrics {"StartTime": 1729737438.5535927, "EndTime": 1729737438.5536013, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8162974071502686, "count": 1, "min": 0.8162974071502686, "max": 0.8162974071502686}}}
# #metrics {"StartTime": 1729737438.5536299, "EndTime": 1729737438.553638, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.8110269832611084, "count": 1, "min": 0.8110269832611084, "max": 0.8110269832611084}}}
# #metrics {"StartTime": 1729737438.553666, "EndTime": 1729737438.5536754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.817973165512085, "count": 1, "min": 0.817973165512085, "max": 0.817973165512085}}}
# [10/24/2024 02:37:18 INFO 139918617806656] #quality_metric: host=algo-1, epoch=13, train absolute_loss_objective <loss>=0.4028714036941528
# [10/24/2024 02:37:18 INFO 139918617806656] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=absolute_loss_objective, value=0.2625151681900024
# [10/24/2024 02:37:18 INFO 139918617806656] Saving model for epoch: 13
# [10/24/2024 02:37:18 INFO 139918617806656] Saved checkpoint to "/tmp/tmp0a82nt92/mx-mod-0000.params"
# [10/24/2024 02:37:18 INFO 139918617806656] Early stop condition met. Stopping training.
# [10/24/2024 02:37:18 INFO 139918617806656] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1729737438.4340796, "EndTime": 1729737438.560875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12100.0, "count": 1, "min": 12100, "max": 12100}, "Total Batches Seen": {"sum": 121.0, "count": 1, "min": 121, "max": 121}, "Max Records Seen Between Resets": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Max Batches Seen Between Resets": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Reset Count": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Number of Records Since Last Reset": {"sum": 800.0, "count": 1, "min": 800, "max": 800}, "Number of Batches Since Last Reset": {"sum": 8.0, "count": 1, "min": 8, "max": 8}}}
# [10/24/2024 02:37:18 INFO 139918617806656] #throughput_metric: host=algo-1, train throughput=6302.864184173353 records/second
# [10/24/2024 02:37:18 WARNING 139918617806656] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/24/2024 02:37:18 WARNING 139918617806656] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2024-10-24 02:37:18.562] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 32, "duration": 0, "num_examples": 1, "num_bytes": 5200}
# [2024-10-24 02:37:18.574] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 34, "duration": 10, "num_examples": 8, "num_bytes": 41600}
# [10/24/2024 02:37:18 INFO 139918617806656] #train_score (algo-1) : ('absolute_loss_objective', 51.13784912109375)
# [10/24/2024 02:37:18 INFO 139918617806656] #train_score (algo-1) : ('mse', 3886.2376171875)
# [10/24/2024 02:37:18 INFO 139918617806656] #train_score (algo-1) : ('absolute_loss', 51.13784912109375)
# [10/24/2024 02:37:18 INFO 139918617806656] #train_score (algo-1) : ('rmse', 62.33969535687113)
# [10/24/2024 02:37:18 INFO 139918617806656] #train_score (algo-1) : ('r2', 0.8965819972331899)
# [10/24/2024 02:37:18 INFO 139918617806656] #train_score (algo-1) : ('mae', 51.13784942626953)
# [10/24/2024 02:37:18 INFO 139918617806656] #quality_metric: host=algo-1, train absolute_loss_objective <loss>=51.13784912109375
# [10/24/2024 02:37:18 INFO 139918617806656] #quality_metric: host=algo-1, train mse <loss>=3886.2376171875
# [10/24/2024 02:37:18 INFO 139918617806656] #quality_metric: host=algo-1, train absolute_loss <loss>=51.13784912109375
# [10/24/2024 02:37:18 INFO 139918617806656] #quality_metric: host=algo-1, train rmse <loss>=62.33969535687113
# [10/24/2024 02:37:18 INFO 139918617806656] #quality_metric: host=algo-1, train r2 <loss>=0.8965819972331899
# [10/24/2024 02:37:18 INFO 139918617806656] #quality_metric: host=algo-1, train mae <loss>=51.13784942626953
# [10/24/2024 02:37:18 INFO 139918617806656] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [10/24/2024 02:37:18 INFO 139918617806656] Saved checkpoint to "/tmp/tmpwoc71dkv/mx-mod-0000.params"
# [10/24/2024 02:37:18 INFO 139918617806656] Test data is not provided.
# #metrics {"StartTime": 1729737436.6486678, "EndTime": 1729737438.5810757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 161.40246391296387, "count": 1, "min": 161.40246391296387, "max": 161.40246391296387}, "epochs": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "check_early_stopping.time": {"sum": 8.087396621704102, "count": 14, "min": 0.17023086547851562, "max": 1.6126632690429688}, "update.time": {"sum": 1712.110996246338, "count": 14, "min": 109.35235023498535, "max": 139.63794708251953}, "finalize.time": {"sum": 15.025615692138672, "count": 1, "min": 15.025615692138672, "max": 15.025615692138672}, "setuptime": {"sum": 3.015756607055664, "count": 1, "min": 3.015756607055664, "max": 3.015756607055664}, "totaltime": {"sum": 2044.3015098571777, "count": 1, "min": 2044.3015098571777, "max": 2044.3015098571777}}}
#
# 2024-10-24 02:37:36 Completed - Training job completed
# Training seconds: 147
# Billable seconds: 147

# %% [markdown]
# # TASK #4: DEPLOY AND TEST THE TRAINED LINEAR LEARNER MODEL

# %%
# Deploying the model to perform inference 

# Content type overrides the data that will be passed to the deployed model, since the deployed model expects data in text/csv format.
# Serializer accepts a single argument, the input data, and returns a sequence of bytes in the specified content type
# Deserializer accepts two arguments, the result data and the response content type, and return a sequence of bytes in the specified content type.

from sagemaker.deserializers import JSONDeserializer
from sagemaker.serializers import CSVSerializer


linear_regressor = linear.deploy(initial_instance_count = 1,
                                 instance_type = 'ml.m4.xlarge',
                                 serializer=CSVSerializer(),
                                 deserializer=JSONDeserializer())
# Out:
# INFO:sagemaker:Creating model with name: linear-learner-2024-10-24-02-38-04-936
# INFO:sagemaker:Creating endpoint-config with name linear-learner-2024-10-24-02-38-04-936
# INFO:sagemaker:Creating endpoint with name linear-learner-2024-10-24-02-38-04-936
# --------!

# %%
# making prediction on the test data

result = linear_regressor.predict(X_test)

# %%
result # results are in Json format
# Out:
# {'predictions': [{'score': 2517.064208984375},
#   {'score': 2066.378173828125},
#   {'score': 2508.14697265625},
#   {'score': 2741.923828125},
#   {'score': 2716.89990234375},
#   {'score': 2288.309326171875},
#   {'score': 2514.404296875},
#   {'score': 2232.01904296875},
#   {'score': 2295.951416015625},
#   {'score': 2533.22216796875},
#   {'score': 2317.14111328125},
#   {'score': 2568.88037109375},
#   {'score': 2636.310546875},
#   {'score': 2543.58203125},
#   {'score': 2321.92724609375},
#   {'score': 2497.466796875},
#   {'score': 2229.771240234375},
#   {'score': 2367.8095703125},
#   {'score': 2807.544921875},
#   {'score': 2435.09033203125},
#   {'score': 2279.84375},
#   {'score': 2156.29345703125},
#   {'score': 2207.878173828125},
#   {'score': 2237.2001953125},
#   {'score': 2373.009521484375},
#   {'score': 2205.93994140625},
#   {'score': 2535.3515625},
#   {'score': 2425.2001953125},
#   {'score': 2208.465576171875},
#   {'score': 2377.123046875},
#   {'score': 2066.376708984375},
